# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Requirement already satisfied: ipython-sql in c:\\users\\dell\\anaconda3\\lib\\site-packages (0.5.0)',
#  'Requirement already satisfied: prettytable in c:\\users\\dell\\anaconda3\\lib\\site-packages (from ipython-sql) (3.10.0)',
#  'Requirement already satisfied: ipython in c:\\users\\dell\\anaconda3\\lib\\site-packages (from ipython-sql) (8.15.0)',
#  'Requirement already satisfied: sqlalchemy>=2.0 in c:\\users\\dell\\anaconda3\\lib\\site-packages (from ipython-sql) (2.0.29)',
#  'Requirement already satisfied: sqlparse in c:\\users\\dell\\anaconda3\\lib\\site-packages (from ipython-sql) (0.4.4)',
#  'Requirement already satisfied: six in c:\\users\\dell\\anaconda3\\lib\\site-packages (from ipython-sql) (1.16.0)',
#  'Requirement already satisfied: ipython-genutils in c:\\users\\dell\\anaconda3\\lib\\site-packages (from ipython-sql) (0.2.0)',
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///mydb.db

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
#◙ MANUEL TABLO OLUŞTURMA

# %%
# %%sql
# CREATE TABLE yeni_tablo(firtsname varchar(20),
#                        lastname varchar(20)); # yeni tablo ve değişen oluştu vede max 20 karakter dedik
# Out:
#  * sqlite:///mydb.db
# Done.
# []

# %%
# %%sql
# INSERT INTO yeni_tablo values("ali","uzaya_git");
# Out:
#  * sqlite:///mydb.db
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO yeni_tablo values("veli","geldi");
# Out:
#  * sqlite:///mydb.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM yeni_tablo
# Out:
#  * sqlite:///mydb.db
# Done.
# [('süleyman kürşat', 'demir'), ('ali', 'uzaya_git'), ('veli', 'geldi')]

# %%
# %%sql
# SELECT * FROM PrOducts LIMIT 5;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type="table"
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Products',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',)]

# %%
# veri tabanı içindeki tabloları gör

# %%
# %%sql
# SELECT * FROM Customers where 1=0;
# Out:
#  * sqlite:///mydb.db
# Done.
# []

# %%
# burada customersin değişknelrine eriştik

# %%
# %%sql
# SELECT CustomerName, City FROM Customers LIMIT 5;
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Alfreds Futterkiste', 'Berlin'),
#  ('Ana Trujillo Emparedados y helados', 'México D.F.'),
#  ('Antonio Moreno Taquería', 'México D.F.'),
#  ('Around the Horn', 'London'),
#  ('Berglunds snabbköp', 'Luleå')]

# %%
# burada tablo içindeki değişkenlerin gözelm değerine eriştik

# %%
# %%sql
# select * from Products LIMIT 3;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %%
# %%sql
# select Price, Price*3, Price*4-41 from Products LIMIT 3;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(18, 54, 31), (19, 57, 35), (10, 30, -1)]

# %%
# matematiksel işlemler

# %%
# takma isism işlemleri # alias:

# %%
# %%sql
# select Price AS yeni_price, Price*3, Price*4-41 AS islemli_price from Products LIMIT 3;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(18, 54, 31), (19, 57, 35), (10, 30, -1)]

# %%
# count tablodaki değerleri saydırma

# %%
# %%sql
# select count(*) AS satırSayisi from Customers
# Out:
#  * sqlite:///mydb.db
# Done.
# [(91,)]

# %%
# order by sırlama yapmak için kullanılır 
# küçükten büyüğe

# %%
# %%sql
# select * from Products ORDER BY Price LIMIT 10;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(13, 'Konbu', 6, 8, '2 kg box', 6),
#  (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7),
#  (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14)]

# %%
# %%sql
# select * from Products ORDER BY Price DESC LIMIT 10;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 435),
#  (38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263),
#  (29, 'Thüringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53),
#  (62, 'Tarte au sucre', 29, 3, '48 pies', 49),
#  (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46)]

# %%
# büyükten küçüğe

# %%
# WHERE filtreme işlemi gibi kullanılır

# %%
# %%sql
# select * from Customers LIMIT 10;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# select * from Customers where Country="Sweden";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (24, 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')]

# %%
#customers içindeki swedenleri seç dedik text string secim

# %%
# %%sql
# select * from Customers where City="Berlin";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')]

# %%
# %%sql
# select * from Customers where not City="Berlin" LIMIT 10;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
# ...

# %%
# berlin dışındakileri geitr dedik

# %%
#numerik ifadeler

# %%
# %%sql
# select * from Customers where PostalCode = 5021;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico')]

# %%
# %%sql
# select * from Customers where PostalCode >= 5021 LIMIT 10 ;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
# ...

# %%
# %%sql
# select * from Customers LIMIT 10;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# select * from Customers where Country="UK"AND City="London";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')]

# %%
# ksısıt belirtmek artıkmak için kullandık and i

# %%
# %%sql
# select * from Customers where Country="UK"OR Country="USA";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (38, 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
# ...

# %%
# %%sql
# select * from Customers where Country="USA"and (City="Berlin" or City="Eugene");
# Out:
#  * sqlite:///mydb.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')]

# %%
# %%sql
# select * from Customers where Country="USA"and PostalCode=97403 and (City="Berlin" or City="Eugene");
# Out:
#  * sqlite:///mydb.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')]

# %%
# ksııtlara numeric kısıt da getirebilir and or kullanımnı gördük

# %%
# in/ not in

# %%
# %%sql
# select * from Customers where CustomerID in(1,3,5,7);
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')]

# %%
# or ifadesini kullanmadan daha kısa filtreledik

# %%
# %%sql
# select * from Customers where Country="USA"and City in("Berlin","Elgin");
# Out:
#  * sqlite:///mydb.db
# Done.
# [(36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')]

# %%
# %%sql
# select * from Customers where Country="USA"and City not in("Berlin","Elgin") LIMIT 10;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA'),
#  (71, 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA'),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA'),
#  (77, 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA'),
# ...

# %%
# like ile secim ifadeler

# %%
# "a%"":" a" ile başlayan değerler
# "%a" : "a"ile biten değerler
# "%or%" : herhangi bir yerde or olan değerler
#"_r%" : ikinci sırada "r " olan değerler
#"a%%": a ile başlayıp en az 3 karakter oluşan değerler
#"a%o": a ile başlayıp "o "ile biten değerler

# %%
# %%sql
# select * from Customers where CustomerName like "%or%";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (40, "La corne d'abondance", 'Daniel Tonini', "67, avenue de l'Europe", 'Versailles', '78000', 'France'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK'),
# ...

# %%
# %%sql
# select * from Customers where CustomerName like "%a";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (30, 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero, 33', 'Sevilla', '41101', 'Spain'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
#  (88, 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil'),
#  (90, 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')]

# %%
# %%sql
# select * from Customers where CustomerName like "a%" and Country like "%co";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# BETWEEN

# %%
# %%sql
# select * from Products LIMIT 10;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %%sql
# select * from Products where Price not between 10 and 19 LIMIT 10;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38),
#  (13, 'Konbu', 6, 8, '2 kg box', 6)]

# %%
# %%sql
# select * from Products where (Price between 10 and 20) and not CategoryID IN (1,2,3);
# Out:
#  * sqlite:///mydb.db
# Done.
# [(36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (54, 'Tourtière', 25, 6, '16 pies', 16),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10)]

# %%
# %%sql
# select ProductName from Products where (Price between 10 and 20) and not CategoryID IN (1,2,3);
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Inlagd Sill',),
#  ('Singaporean Hokkien Fried Mee',),
#  ('Spegesild',),
#  ('Tourtière',),
#  ('Escargots de Bourgogne',),
#  ('Röd Kaviar',),
#  ('Longlife Tofu',)]

# %%
# AGGREGATİON FONKSİYONLAR: TEMEL İSTATİKSEL İŞLEMLER

# %%
# %%sql
# select min(Price) from Products
# Out:
#  * sqlite:///mydb.db
# Done.
# [(6,)]

# %%
# %%sql
# select min(Price),max(Price) from Products
# Out:
#  * sqlite:///mydb.db
# Done.
# [(6, 435)]

# %%
# %%sql
# select avg(Price) from Products
# Out:
#  * sqlite:///mydb.db
# Done.
# [(39.15584415584416,)]

# %%
# ortalama değer yukarıdaki

# %%
# toplama

# %%
# %%sql
# select sum(Price) from Products
# Out:
#  * sqlite:///mydb.db
# Done.
# [(3015,)]

# %%
# %%sql
# select min(Price),max(Price),avg(Price),sum(Price) from Products
# Out:
#  * sqlite:///mydb.db
# Done.
# [(6, 435, 39.15584415584416, 3015)]

# %%
# group by ve aggregation yukardaki fonksiyonlar agregation fnok lar

# %%
# %%sql
# select count(CustomerID) as muster_sayisi,Country from Customers group by Country order by muster_sayisi desc;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
# ürün kategrilerin fiyat ortalaması
# belirli bir gruplamama sınıflandırmada işlem için group by kullanılır

# %%
# %%sql
# select avg(Price)as ort_fiyat, CategoryID from Products group by CategoryID;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(42.75, 1),
#  (28.25, 2),
#  (33.76923076923077, 3),
#  (74.9, 4),
#  (23.571428571428573, 5),
#  (55.166666666666664, 6),
#  (32.2, 7),
#  (26.5, 8)]

# %%
# JOIN işlemleri
# left join : soldaki tabloyla kesişen sağdaki değerleri birleştiriir

# %%
# %%sql
# select * from Products right JOIN Categories ON Products.CategoryID=Categories.CategoryID LIMIT 3
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings')]

# %%
# %%sql
# select Products.ProductName,Categories.CategoryID,CategoryName  from Products right JOIN Categories ON Products.CategoryID=Categories.CategoryID LIMIT 3
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments')]

# %%
# %%sql
# select pr.ProductName,ca.CategoryID,ca.CategoryName  from Products as pr right JOIN Categories as ca ON pr.CategoryID=ca.CategoryID LIMIT 3
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments')]

# %%
# kısaltma yaparak daha az kod yazdık

# %%
# %%sql
# select pr.ProductName,ca.CategoryID,ca.CategoryName  from Products  pr right JOIN Categories  ca ON pr.CategoryID=ca.CategoryID LIMIT 3
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments')]

# %%
# inner join iki tabloda kesişen değerleri tek tabloda yapma

# %%
# %%sql
# select Orders.OrderID,Customers.CustomerName from Orders inner join Customers on Orders.CustomerID=Customers.CustomerID
# Out:
#  * sqlite:///mydb.db
# Done.
# [(10248, 'Wilman Kala'),
#  (10249, 'Tradição Hipermercados'),
#  (10250, 'Hanari Carnes'),
#  (10251, 'Victuailles en stock'),
#  (10252, 'Suprêmes délices'),
#  (10253, 'Hanari Carnes'),
#  (10254, 'Chop-suey Chinese'),
#  (10255, 'Richter Supermarkt'),
#  (10256, 'Wellington Importadora'),
#  (10257, 'HILARIÓN-Abastos'),
#  (10258, 'Ernst Handel'),
#  (10259, 'Centro comercial Moctezuma'),
#  (10260, 'Old World Delicatessen'),
#  (10261, 'Que Delícia'),
#  (10262, 'Rattlesnake Canyon Grocery'),
#  (10263, 'Ernst Handel'),
#  (10264, 'Folk och fä HB'),
#  (10265, 'Blondel père et fils'),
#  (10266, 'Wartian Herkku'),
#  (10267, 'Frankenversand'),
#  (10268, 'GROSELLA-Restaurante'),
#  (10269, 'White Clover Markets'),
#  (10270, 'Wartian Herkku'),
#  (10271, 'Split Rail Beer & Ale'),
#  (10272, 'Rattlesnake Canyon Grocery'),
#  (10273, 'QUICK-Stop'),
#  (10274, 'Vins et alcools Chevalier'),
#  (10275, 'Magazzini Alimentari Riuniti'),
# ...

# %%
# %%sql
# select count(*) from (select Orders.OrderID,Customers.CustomerName from Orders inner join Customers on Orders.CustomerID=Customers.CustomerID);
# Out:
#  * sqlite:///mydb.db
# Done.
# [(196,)]

# %%
import pandas as pd

# %%
# %%sql
# select count(*) from (select Orders.OrderID,Customers.CustomerName from Orders inner join Customers on Orders.CustomerID=Customers.CustomerID);
# Out:
#  * sqlite:///mydb.db
# Done.
# [(196,)]

# %%
df = %sql select count(*) from (select Orders.OrderID,Customers.CustomerName from Orders inner join Customers on Orders.CustomerID=Customers.CustomerID);
df
# Out:
#  * sqlite:///mydb.db
# Done.
# [(196,)]

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.head()
#
# AttributeError: 'ResultSet' object has no attribute 'head'

# %%
dff = pd.DataFrame(df, columns = ["MUS_SAY"])

# %%
dff
# Out:
#    MUS_SAY
# 0      196

# %%
dff.head()
# Out:
#    MUS_SAY
# 0      196

# %%
# pandas dataframe dönüşümü

# %%
# dff.plot.barh(x = "ULKE", y = "MUS_SAY");dff.plot.barh.(x())

# %%
import sqlite3

# %%
# sqllite 3

# %%
conn=sqlite3.connect("mydb.db")

# %%
# ?conn

# %%
c=conn.cursor()

# %%
# sorguları çalıştırır cursor

# %%
# ?c

# %%
pd.read_sql
# Out:
# <function pandas.io.sql.read_sql(sql, con, index_col: 'str | list[str] | None' = None, coerce_float: 'bool' = True, params=None, parse_dates=None, columns: 'list[str] | None' = None, chunksize: 'int | None' = None, dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>, dtype: 'DtypeArg | None' = None) -> 'DataFrame | Iterator[DataFrame]'>

# %%
pd.read_sql("SELECT COUNT(CustomerID) AS MUSTERI_SAYISI, Country FROM Customers GROUP BY Country;", conn)
# Out:
#     MUSTERI_SAYISI      Country
# 0                3    Argentina
# 1                2      Austria
# 2                2      Belgium
# 3                9       Brazil
# 4                3       Canada
# 5                2      Denmark
# 6                2      Finland
# 7               11       France
# 8               11      Germany
# 9                1      Ireland
# 10               3        Italy
# 11               5       Mexico
# 12               1       Norway
# 13               1       Poland
# 14               2     Portugal
# 15               5        Spain
# 16               2       Sweden
# 17               2  Switzerland
# 18               7           UK
# 19              13          USA
# 20               4    Venezuela

# %%
ab=pd.read_sql("""SELECT 
COUNT(CustomerID) AS MUSTERI_SAYISI, Country 
FROM 
Customers 
GROUP BY Country;""", conn)

# %%
ab
# Out:
#     MUSTERI_SAYISI      Country
# 0                3    Argentina
# 1                2      Austria
# 2                2      Belgium
# 3                9       Brazil
# 4                3       Canada
# 5                2      Denmark
# 6                2      Finland
# 7               11       France
# 8               11      Germany
# 9                1      Ireland
# 10               3        Italy
# 11               5       Mexico
# 12               1       Norway
# 13               1       Poland
# 14               2     Portugal
# 15               5        Spain
# 16               2       Sweden
# 17               2  Switzerland
# 18               7           UK
# 19              13          USA
# 20               4    Venezuela

# %%
# conn.close

# %%
c.execute("select CustomerName from Customers LIMIT 5;")

# %%
c.fetchone()
# Out:
# ('Alfreds Futterkiste',)

# %%
c.fetchall()
# Out:
# [('Ana Trujillo Emparedados y helados',),
#  ('Antonio Moreno Taquería',),
#  ('Around the Horn',),
#  ('Berglunds snabbköp',)]

# %%
for row in c.execute("select CustomerName from Customers LIMIT 5;"):
    print(row)
# Out:
# ('Alfreds Futterkiste',)
# ('Ana Trujillo Emparedados y helados',)
# ('Antonio Moreno Taquería',)
# ('Around the Horn',)
# ('Berglunds snabbköp',)

# %%
# orders tablosunda kaç tane eşsiz müşteri vardır? dıstımct eşsiz

# %%
# %%sql
# select count(DISTINCT CustomerID) from Orders;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(74,)]

# %%
# customer tablosunda ahngi ülkeden kaçar tane müşteri oldugunu bulunuz

# %%
# %%sql
# select count(CustomerID) as muster_sayisi,Country from Customers group by Country order by muster_sayisi desc;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
# müşterilerin brezilya yada usa olanları bulunuz

# %%
# %%sql
# select * from Customers where Country="USA" or Country="Brazil";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (34, 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
# ...

# %%
# önce ülkehye sonra şehre göre grup by işlemi yapıp bu kırılımda müşteri sayısnı bulunuz

# %%
# %%sql
# SELECT COUNT(CustomerID), Country, City FROM Customers GROUP BY Country, City;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(3, 'Argentina', 'Buenos Aires'),
#  (1, 'Austria', 'Graz'),
#  (1, 'Austria', 'Salzburg'),
#  (1, 'Belgium', 'Bruxelles'),
#  (1, 'Belgium', 'Charleroi'),
#  (1, 'Brazil', 'Campinas'),
#  (1, 'Brazil', 'Resende'),
#  (3, 'Brazil', 'Rio de Janeiro'),
#  (4, 'Brazil', 'São Paulo'),
#  (1, 'Canada', 'Montréal'),
#  (1, 'Canada', 'Tsawassen'),
#  (1, 'Canada', 'Vancouver'),
#  (1, 'Denmark', 'København'),
#  (1, 'Denmark', 'Århus'),
#  (1, 'Finland', 'Helsinki'),
#  (1, 'Finland', 'Oulu'),
#  (1, 'France', 'Lille'),
#  (1, 'France', 'Lyon'),
#  (1, 'France', 'Marseille'),
#  (2, 'France', 'Nantes'),
#  (2, 'France', 'Paris'),
#  (1, 'France', 'Reims'),
#  (1, 'France', 'Strasbourg'),
#  (1, 'France', 'Toulouse'),
#  (1, 'France', 'Versailles'),
#  (1, 'Germany', 'Aachen'),
#  (1, 'Germany', 'Berlin'),
#  (1, 'Germany', 'Brandenburg'),
#  (1, 'Germany', 'Cunewalde'),
#  (1, 'Germany', 'Frankfurt a.M.'),
#  (1, 'Germany', 'Köln'),
# ...

# %%
# müşterilerin adreslerinin herahngi bir yerinde "da" ifadesi ggeçen tüm adreslerib bulunuz

# %%
# %%sql
# select * from Customers where Address like "%da%";
# Out:
#  * sqlite:///mydb.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (28, 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal'),
#  (54, 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina'),
#  (60, 'Princesa Isabel Vinhoss', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
# ...

# %%
# germany-berlin de yaşayan müşterieln isimleri nerlerdir

# %%
# %%sql
# SELECT CustomerName
# FROM Customers
# WHERE Country = 'Germany' AND City = 'Berlin';
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Alfreds Futterkiste',)]

# %%
# canada da yaşayıp isimlerinde "in" ifadesi geçen müşterileri bukunuz

# %%
# %%sql
# select CustomerName from Customers
# where Country="Canada" and CustomerName like "%in%";
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Laughing Bacchus Wine Cellars',)]

# %%
# %%sql
# SELECT Price, ProductName
# FROM Products
# WHERE Price BETWEEN 40 AND 90;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(40, 'Northwoods Cranberry Sauce'),
#  (43, 'Genen Shouyu'),
#  (62, 'Carnarvon Tigers'),
#  (43, 'Teatime Chocolate Biscuits'),
#  (81, "Sir Rodney's Marmalade"),
#  (43, 'Guaraná Fantástica'),
#  (43, 'Schoggi Schokolade'),
#  (45, 'Rössle Sauerkraut'),
#  (43, 'Geitost'),
#  (43, 'Boston Crab Meat'),
#  (46, 'Ipoh Coffee'),
#  (43, 'Røgede sild'),
#  (43, 'Zaanse koeken'),
#  (53, 'Manjimup Dried Apples'),
#  (43, 'Ravioli Angelo'),
#  (55, 'Raclette Courdavault'),
#  (43, "Sirop d'érable"),
#  (49, 'Tarte au sucre'),
#  (43, 'Vegie-spread'),
#  (43, 'Louisiana Fiery Hot Pepper Sauce'),
#  (45, 'Scottish Longbreads')]

# %%
# fiyatı 30 tlden büyük olan isimlerini,fıyatlarını ve fiyatlarını karesini bulunuz ve yeiden isimlendir

# %%
# %%sql
# SELECT Price as ürün_fiyat, Price*Price AS fiyat_karesi, ProductName as urun_ismi
# FROM Products
# WHERE Price >= 30;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(30, 900, "Uncle Bob's Organic Dried Pears"),
#  (40, 1600, 'Northwoods Cranberry Sauce'),
#  (97, 9409, 'Mishi Kobe Niku'),
#  (31, 961, 'Ikura'),
#  (38, 1444, 'Queso Manchego La Pastora'),
#  (43, 1849, 'Genen Shouyu'),
#  (39, 1521, 'Alice Mutton'),
#  (62, 3844, 'Carnarvon Tigers'),
#  (43, 1849, 'Teatime Chocolate Biscuits'),
#  (81, 6561, "Sir Rodney's Marmalade"),
#  (43, 1849, 'Guaraná Fantástica'),
#  (31, 961, 'Gumbär Gummibärchen'),
#  (43, 1849, 'Schoggi Schokolade'),
#  (45, 2025, 'Rössle Sauerkraut'),
#  (123, 15129, 'Thüringer Rostbratwurst'),
#  (435, 189225, 'Gorgonzola Telino'),
#  (32, 1024, 'Mascarpone Fabioli'),
#  (43, 1849, 'Geitost'),
#  (263, 69169, 'Côte de Blaye'),
#  (43, 1849, 'Boston Crab Meat'),
#  (46, 2116, 'Ipoh Coffee'),
#  (43, 1849, 'Røgede sild'),
#  (43, 1849, 'Zaanse koeken'),
#  (53, 2809, 'Manjimup Dried Apples'),
#  (32, 1024, 'Perth Pasties'),
#  (38, 1444, 'Gnocchi di nonna Alice'),
# ...

# %%
# products tablosundaki category _id lerini yanei kategorilerin isimleri nelerdir

# %%
# %%sql
# SELECT Categories.CategoryName, Products.CategoryID
# FROM Products
# INNER JOIN Categories ON Products.CategoryID = Categories.CategoryID
# GROUP BY Categories.CategoryID, Categories.CategoryName;
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Beverages', 1),
#  ('Condiments', 2),
#  ('Confections', 3),
#  ('Dairy Products', 4),
#  ('Grains/Cereals', 5),
#  ('Meat/Poultry', 6),
#  ('Produce', 7),
#  ('Seafood', 8)]

# %%
# usa da yaşayan müşterilerin kazandırdığı toplam kazancı bulunuz

# %%
# %%sql
# SELECT SUM(Price) AS total_price
# FROM Customers, Products
# WHERE Country = 'USA';
# Out:
#  * sqlite:///mydb.db
# Done.
# [(39195,)]

# %%
 # product tablosundaki categoryıd lerin isimlerini bulunuz ve sonrasında kategori başına ortalama fiyat bulunuz

# %%
# %%sql
# SELECT AVG(Price), CategoryName
# FROM Products
# LEFT JOIN Categories on Products.CategoryID = Categories.CategoryID
# GROUP BY CategoryName;
# Out:
#  * sqlite:///mydb.db
# Done.
# [(1, 'Beverages', 42.75),
#  (2, 'Condiments', 28.25),
#  (3, 'Confections', 33.76923076923077),
#  (4, 'Dairy Products', 74.9),
#  (5, 'Grains/Cereals', 23.571428571428573),
#  (6, 'Meat/Poultry', 55.166666666666664),
#  (7, 'Produce', 32.2),
#  (8, 'Seafood', 26.5)]

# %%
# çalışanların (emplyod) isimleri ile birlikte yaptıkları toplam satışları sıralayunınz

# %%
# %%sql
# SELECT em.FirstName, SUM(p.Price) toplam_satis
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Employees em on o.EmployeeID = em.EmployeeID
# GROUP BY o.EmployeeID
# ORDER BY toplam_satis DESC;
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Margaret', 5515),
#  ('Nancy', 4353),
#  ('Janet', 3048),
#  ('Michael', 2981),
#  ('Laura', 2380),
#  ('Robert', 1852),
#  ('Andrew', 1550),
#  ('Steven', 1408),
#  ('Anne', 520)]

# %%
# germany verilen siparişlerimn kategorilerine göre ortalam fiyat nedir

# %%
# %%sql
# SELECT ca.CategoryName, AVG(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID
# WHERE cu.Country = 'Germany' GROUP BY CategoryName;
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Beverages', 20.5),
#  ('Condiments', 34.0),
#  ('Confections', 40.0),
#  ('Dairy Products', 151.64705882352942),
#  ('Grains/Cereals', 22.142857142857142),
#  ('Meat/Poultry', 30.2),
#  ('Produce', 30.75),
#  ('Seafood', 27.09090909090909)]

# %%
# germany yada usa den verilen siparişlerin kategorlirne göre ort fiyat nedir

# %%
# %%sql
# SELECT ca.CategoryName, AVG(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID
# WHERE cu.Country = 'Germany' OR cu.Country = 'USA' GROUP BY CategoryName;
# Out:
#  * sqlite:///mydb.db
# Done.
# [('Beverages', 29.88888888888889),
#  ('Condiments', 34.72727272727273),
#  ('Confections', 39.92307692307692),
#  ('Dairy Products', 131.75862068965517),
#  ('Grains/Cereals', 29.846153846153847),
#  ('Meat/Poultry', 46.75),
#  ('Produce', 28.625),
#  ('Seafood', 25.6)]

# %%
# haziran temmuz ağustos aylarında verieln siparişlerin ort fiyat nedir

# %%
# %%sql
# SELECT AVG(Products.Price)
# FROM Products
# LEFT JOIN OrderDetails on OrderDetails.ProductID = products.ProductID
# LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID
# WHERE OrderDate like '%07%' or OrderDate like '%08%' or OrderDate like '%09%';
# Out:
#  * sqlite:///mydb.db
# Done.
# [(39.71891891891892,)]

# %%
# müşterileirn 1997 yılına ait siparişlerinin max miktarlarını bulup müşteri isimleri ile büyükten küçüğw doğru sıralayınız

# %%
# sipariş yılı 1997 olan sipariişleri alan alışanları sipariş alma sayılarına göre sıralayınız
